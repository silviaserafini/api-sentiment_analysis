# %% [markdown]
# # Use of the Slack Api to fetch the history of the channel

# %%
import requests 
import os
from dotenv import load_dotenv
import pandas as pd
import nltk
import ast
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity as distance
from src.app import app
from pymongo import MongoClient
from src.helpers.errorHandler import errorHandler ,Error404 ,APIError
from src.config import DBURL
from bson.json_util import dumps
from bson import ObjectId
import json
load_dotenv()

# Load the apikey
token = os.getenv("TOKENSLACK")
channel=os.getenv('CHANNEL')
print("WE HAVE TOKEN") if token else print("NO TOKEN FOUND")
print("WE HAVE CHANNEL") if channel else print("NO CHANNEL FOUND")
# Out:
# WE HAVE TOKEN
# WE HAVE CHANNEL

# %%
url='https://slack.com/api/channels.history?token={token}&channel={channel}&count=678&pretty=1'

# %%
from slacker import Slacker
# Authenticate with slacker
slack = Slacker(token)

# %%
# Check for success
if slack.api.test().successful:
    print(
        f"Connected to {slack.team.info().body['team']['name']}.")
else:
    print('Try Again!')
# Out:
# Connected to Data Mad March 2020.

# %%
r = slack.channels.history( channel=channel,count=678)

history = r.body

# %%
#Retrive all the text and user
chat=[]
for mes in history['messages']:
    try:
        chat.append({
            'user': mes['user'],
            'text': mes['text']
        })
    except:
        continue

# %%
df=pd.DataFrame(chat)

# %%
display(df.head())
# Out:
#           user                                               text
# 0  U010F1FCBGU                                     gracias tío!!!
# 1  U010H826R1D  Chicos, ya tenéis la semana 3 de clases en mi ...
# 2  U010F1FCBGU  <https://www.aprendemachinelearning.com/ejerci...
# 3  U010F1FCBGU                         Buenas! Dejo esto por aquí
# 4  U0102M41WV8                             muchas gracias david!!

# %% [markdown]
# # Adding of the datamad0320 chat to the database

# %%
#set of datamad0320 users
users_unique=set(df['user'].values)

# %%
#add the users to mongodb database
usersIds={}
for username in users_unique:
    r = requests.get(f'http://localhost:3500///user/create/{username}')
    usersIds[username]=(r.json()['user_id'])

# %%
list(usersIds.values())[0:5]
# Out:
# ['5eaec9762908c7e2052a6ab8',
#  '5eaec9762908c7e2052a6ab9',
#  '5eaec9762908c7e2052a6aba',
#  '5eaec9762908c7e2052a6abb',
#  '5eaec9762908c7e2052a6abc']

# %%
#creation of the new chat dataMad0320
chat_name='dataMad0320'
users_ids=list(usersIds.values())
r = requests.get(f'http://localhost:3500//chat/create?ids={users_ids}&name={chat_name}')
chatId=r.json()['chat_id']

# %%
chatId
# Out:
# '5eaec9f02908c7e2052a6ad0'

# %%
#add the messages to the chat
messagesIds=[]
for mes in chat:#chat is a list of dictionaties {'user':user,'text':text}
    user=mes['user']
    user_id=usersIds[user]
    text=mes['text']
    r = requests.get(f'http://localhost:3500///chat/{chatId}/addmessage?user_id={user_id}&text={text}')
    messagesIds.append(r.json()['message_id'])

# %% [markdown]
# # Sentiment analysis of the chat

# %%
from classifier import *
clf = SentimentClassifier()
clf.predict(e)
r = requests.get(f'http://localhost:3500///chat/{chatId}/sentiment')
r.json()['chat_sentiment']
# Out:
# {'5eaeca2f2908c7e2052a6ad1': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'gracias tío!!!'},
#  '5eaeca2f2908c7e2052a6ad2': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Chicos, ya tenéis la semana 3 de clases en mi google drive para descargar. Solo hay cuatro videos porque el lunes era día de proyecto. <https://drive.google.com/open?id=1H1T8nQeZzpO4HzLB3v7lfUabko7WJfoS>'},
#  '5eaeca2f2908c7e2052a6ad3': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://www.aprendemachinelearning.com/ejercicio-nlp-cuentos-de-hernan-casciari-python-espanol/>'},
#  '5eaeca2f2908c7e2052a6ad4': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Buenas! Dejo esto por aquí'},
#  '5eaeca302908c7e2052a6ad5': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'muchas gracias david!!'},
#  '5eaeca302908c7e2052a6ad6': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'hay uno de sistemas de recomendación...:nerd_face::joy:'},
#  '5eaeca302908c7e2052a6ad7': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'En este enlace tenéis lo mismo, hay mucho material de muchas ramas, y se descargan rapidito.'},
#  '5eaeca302908c7e2052a6ad8': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://www.genbeta.com/actualidad/springer-ha-habilitado-descarga-gratuita-casi-500-libros-que-suelen-costar-100-euros-incluyendo-50-programacion>'},
#  '5eaeca302908c7e2052a6ad9': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca302908c7e2052a6ada': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca312908c7e2052a6adb': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<!channel> Animo chicos!! Ya queda menos para que os den el carné de puto crack de python'},
#  '5eaeca312908c7e2052a6adc': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca312908c7e2052a6add': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca312908c7e2052a6ade': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://www.codewars.com/kata/5a5cdb07fd56cbdd3c00005b> *LA KATA DE HOY* :slightly_smiling_face:'},
#  '5eaeca312908c7e2052a6adf': {'score': {'compound': -0.296,
#    'neg': 0.306,
#    'neu': 0.694,
#    'pos': 0.0},
#   'text': 'no, al menos de momento jajaja'},
#  '5eaeca312908c7e2052a6ae0': {'score': {'compound': -0.7707,
#    'neg': 0.49,
#    'neu': 0.51,
#    'pos': 0.0},
#   'text': 'Bieen!! Y no te salta error cuando no está? Voy a probarlo a ver...'},
#  '5eaeca322908c7e2052a6ae1': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'lo he conseguido con un condicional if request.args:'},
#  '5eaeca322908c7e2052a6ae2': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'gracias, Roberto!'},
#  '5eaeca322908c7e2052a6ae3': {'score': {'compound': 0.4003,
#    'neg': 0.0,
#    'neu': 0.839,
#    'pos': 0.161},
#   'text': 'solo he usado GET hasta ahora, me ha funcionado para crear users, chats y enviar mensajes!'},
#  '5eaeca322908c7e2052a6ae4': {'score': {'compound': 0.34,
#    'neg': 0.0,
#    'neu': 0.833,
#    'pos': 0.167},
#   'text': 'alguien ya ha conseguido insertar algo en la base de datos mediante POST?'},
#  '5eaeca322908c7e2052a6ae5': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Gracias!!'},
#  '5eaeca332908c7e2052a6ae6': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Hola chicos! Yo estoy leyendo esta documentación y me está ayudando bastante para crear una database, collecciones en mongo e insertar datos en cada colección, la dejo por aquí también! :slightly_smiling_face: <https://www.w3schools.com/python/python_mongodb_insert.asp>'},
#  '5eaeca332908c7e2052a6ae7': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Justo estaba pensando en como hacer para que los parámetros sean opcionales :sweat_smile:'},
#  '5eaeca332908c7e2052a6ae8': {'score': {'compound': -0.296,
#    'neg': 0.136,
#    'neu': 0.864,
#    'pos': 0.0},
#   'text': 'Nada :slightly_smiling_face: Aunque ahora tengo problemas cuando no le paso query params en el request...'},
#  '5eaeca332908c7e2052a6ae9': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Muy bueno! Gracias Flori!'},
#  '5eaeca332908c7e2052a6aea': {'score': {'compound': 0.34,
#    'neg': 0.0,
#    'neu': 0.821,
#    'pos': 0.179},
#   'text': 'me ha ayudado con los query params, por si os sirve\n<https://www.google.com/search?client=ubuntu'},
#  '5eaeca332908c7e2052a6aeb': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Marchando!'},
#  '5eaeca342908c7e2052a6aec': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '¿puedes modificar tu mensaje y añadir esto al texto? <@U0102M4DJHG> grazie :slightly_smiling_face:'},
#  '5eaeca342908c7e2052a6aed': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'OBJECT_ID\xa0: 1:\notro_ID\xa0:-1:'},
#  '5eaeca342908c7e2052a6aee': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca342908c7e2052a6aef': {'score': {'compound': 0.8636,
#    'neg': 0.0,
#    'neu': 0.317,
#    'pos': 0.683},
#   'text': 'Great minds thinks alike, Jesús XD'},
#  '5eaeca342908c7e2052a6af0': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'ajajajaja'},
#  '5eaeca352908c7e2052a6af1': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'OBJECT_ID\xa0: 1:\notro_ID\xa0:-1:\n\n(De parte de  <@U010EAT0XFF>)'},
#  '5eaeca352908c7e2052a6af2': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca352908c7e2052a6af3': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca352908c7e2052a6af4': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca352908c7e2052a6af5': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://http.cat/>'},
#  '5eaeca352908c7e2052a6af6': {'score': {'compound': 0.34,
#    'neg': 0.0,
#    'neu': 0.789,
#    'pos': 0.211},
#   'text': 'Me ha parecido interesante y es guay, echadle un ojo:\n<https://hackernoon.com/how-i-got-banned-from-codewars-c21ad6ebee1e>'},
#  '5eaeca362908c7e2052a6af7': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca362908c7e2052a6af8': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'La kata de hoy <https://www.codewars.com/kata/5a5f9f80f5dc3f942b002309> <https://media.giphy.com/media/11s7Ke7jcNxCHS/giphy.gif>'},
#  '5eaeca362908c7e2052a6af9': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '```sudo update-alternatives --config java```\n'},
#  '5eaeca362908c7e2052a6afa': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://www.digitalocean.com/community/tutorials/como-instalar-java-con-apt-en-ubuntu-18-04-es>'},
#  '5eaeca362908c7e2052a6afb': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'y que la ponga como predeterminada'},
#  '5eaeca372908c7e2052a6afc': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'que se instale la versión 8 de Java'},
#  '5eaeca372908c7e2052a6afd': {'score': {'compound': 0.34,
#    'neg': 0.0,
#    'neu': 0.789,
#    'pos': 0.211},
#   'text': 'ha tneido problemas con pyspark a la hora de usar parallelize'},
#  '5eaeca372908c7e2052a6afe': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Si alguien con Ubuntu 18'},
#  '5eaeca372908c7e2052a6aff': {'score': {'compound': -0.4019,
#    'neg': 0.137,
#    'neu': 0.863,
#    'pos': 0.0},
#   'text': 'A alguien más le sale este error en el segundo lab? `TypeError: an integer is required (got type bytes)`'},
#  '5eaeca372908c7e2052a6b00': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://www.educba.com/f-test-formula/>'},
#  '5eaeca372908c7e2052a6b01': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca382908c7e2052a6b02': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://www.cienciadedatos.net/documentos/19_anova>'},
#  '5eaeca382908c7e2052a6b03': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://pythonfordatascience.org/anova-2-way-n-way/>'},
#  '5eaeca382908c7e2052a6b04': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': ':pikachu_dance:'},
#  '5eaeca382908c7e2052a6b05': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://www.statisticshowto.com/probability-and-statistics/f-statistic-value-test/>'},
#  '5eaeca382908c7e2052a6b06': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'aquí te lo pone por pasitos'},
#  '5eaeca392908c7e2052a6b07': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca392908c7e2052a6b08': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'ajajaj'},
#  '5eaeca392908c7e2052a6b09': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'para el/la que lo pueda entender'},
#  '5eaeca392908c7e2052a6b0a': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca392908c7e2052a6b0b': {'score': {'compound': 0.0772,
#    'neg': 0.0,
#    'neu': 0.947,
#    'pos': 0.053},
#   'text': 'Os dejo esto por aquí que os puede servir en el challenge 2 del *lab-correlation-tests-with-scipy*, cuando tenéis que hacer la *ANOVA table* y *la C funtion* <https://www.statsmodels.org/stable/examples/notebooks/generated/formulas.html>'},
#  '5eaeca3a2908c7e2052a6b0c': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Por si alguien está teniendo problemas con pyspark (sobre todo para que se abra en jupyter), en este artículo te dicen las variables que hay que añadir al zshrc (o bashrc) para que funcione\n\n\n\n<https://medium.com/sicara/get-started-pyspark-jupyter-guide-tutorial-ae2fe84f594f>'},
#  '5eaeca3a2908c7e2052a6b0d': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '¡Hola! Los labs de hoy:\n• <https://github.com/ironhack-datalabs/datamad0320/tree/master/module-2/lab-correlation-tests-with-scipy>\n• <https://github.com/ironhack-datalabs/datamad0320/tree/master/module-3/lab-apache-spark>'},
#  '5eaeca3a2908c7e2052a6b0e': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://github.com/boyander/runpyspark>'},
#  '5eaeca3a2908c7e2052a6b0f': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://s3.amazonaws.com/assets.datacamp.com/blog_assets/PySpark_SQL_Cheat_Sheet_Python.pdf>'},
#  '5eaeca3a2908c7e2052a6b10': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://www.codewars.com/kata/550f22f4d758534c1100025a> :earth_asia: YA ESTÁ LA KATA, ¡a ver si os orientáis un poquito!\n<https://media.giphy.com/media/9aOWMFD0kqXGU/giphy.gif>'},
#  '5eaeca3b2908c7e2052a6b11': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca3b2908c7e2052a6b12': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '¡Buenos días! En un par de semanitas os será muy útil :slightly_smiling_face:  <https://www.engadget.com/2016/10/01/google-releases-massive-visual-databases-for-machine-learning/>'},
#  '5eaeca3b2908c7e2052a6b13': {'score': {'compound': -0.7096,
#    'neg': 0.056,
#    'neu': 0.944,
#    'pos': 0.0},
#   'text': "`The frequency response of the Butterworth filter is maximally flat (i.e. has no ripples) in the passband and rolls off towards zero in the stopband.[2] When viewed on a logarithmic Bode plot, the response slopes off linearly towards negative infinity. A first-order filter's response rolls off at −6 dB per octave (−20 dB per decade) (all first-order lowpass filters have the same normalized frequency response). A second-order filter decreases at −12 dB per octave, *a third-order at −18 dB and so on*. Butterworth filters have a monotonically changing magnitude function with ω, unlike other filter types that have non-monotonic ripple in the passband and/or the stopband.`"},
#  '5eaeca3b2908c7e2052a6b14': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'qué tennnnnso, siempre me lío'},
#  '5eaeca3b2908c7e2052a6b15': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'y lo que antes era rechazar, es rechazar rechazar el rechazo jajajajaja'},
#  '5eaeca3c2908c7e2052a6b16': {'score': {'compound': 0.34,
#    'neg': 0.0,
#    'neu': 0.789,
#    'pos': 0.211},
#   'text': 'si lo lees 3 veces, a la 3, ha cambiado el orden'},
#  '5eaeca3c2908c7e2052a6b17': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Grande Jesus!!!'},
#  '5eaeca3c2908c7e2052a6b18': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'jajaj'},
#  '5eaeca3c2908c7e2052a6b19': {'score': {'compound': -0.9571,
#    'neg': 0.128,
#    'neu': 0.872,
#    'pos': 0.0},
#   'text': 'The null hypothesis of the test is that the time series can be represented by a unit root, that it is not stationary (has some time-dependent structure). The alternate hypothesis (rejecting the null hypothesis) is that the time series is stationary.\n• *Null Hypothesis (H0)*: If failed to be rejected, it suggests the time series has a unit root, meaning it is non-stationary. It has some time dependent structure.\n• *Alternate Hypothesis (H1)*: The null hypothesis is rejected; it suggests the time series does not have a unit root, meaning it is stationary. It does not have time-dependent structure.\nWe interpret this result using the p-value from the test. A p-value below a threshold (such as 5% or 1%) suggests we reject the null hypothesis (stationary), otherwise\xa0a p-value above the threshold suggests we fail to reject the null hypothesis (non-stationary).\n• *p-value '},
#  '5eaeca3c2908c7e2052a6b1a': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'y aquí mascadito'},
#  '5eaeca3d2908c7e2052a6b1b': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '¡Gracias por compartirlo Jesús! :slightly_smiling_face:'},
#  '5eaeca3d2908c7e2052a6b1c': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://machinelearningmastery.com/time-series-data-stationary-python/>'},
#  '5eaeca3d2908c7e2052a6b1d': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Por si a alguien le sirve, aquí también está biuen explicado'},
#  '5eaeca3d2908c7e2052a6b1e': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://github.com/ironhack-datalabs/datamad0320/tree/master/module-2/lab-time-series>  <http://www.insightsbot.com/augmented-dickey-fuller-test-in-python/>'},
#  '5eaeca3d2908c7e2052a6b1f': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://www.w3schools.com/sql/func_mysql_cast.asp>'},
#  '5eaeca3e2908c7e2052a6b20': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca3e2908c7e2052a6b21': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca3e2908c7e2052a6b22': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Gente! Ya está la semana dos subida a mi google drive! (<https://drive.google.com/open?id=1H1T8nQeZzpO4HzLB3v7lfUabko7WJfoS>). Id descargando la primera que en unos días la borro para dejar espacio a la tercera! :warning:'},
#  '5eaeca3e2908c7e2052a6b23': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Vuelve SQL!!!! Que sé que lo echábais de menos!!!! :mouse: <https://www.codewars.com/kata/580d08b5c049aef8f900007c>'},
#  '5eaeca3e2908c7e2052a6b24': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Para entender los errores estadísticos...'},
#  '5eaeca3f2908c7e2052a6b25': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Y yo que lo más que aspiraba era a diferenciar perritos de gatitos :open_mouth:'},
#  '5eaeca3f2908c7e2052a6b26': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'con un dataset de kaggle :wink:'},
#  '5eaeca3f2908c7e2052a6b27': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'jajajajajajaja que sí Anaaaaaaa, de verdad, ya verás'},
#  '5eaeca3f2908c7e2052a6b28': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca3f2908c7e2052a6b29': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Dentro de poco podréis hacer cosas similares...'},
#  '5eaeca402908c7e2052a6b2a': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': ':slightly_smiling_face:'},
#  '5eaeca402908c7e2052a6b2b': {'score': {'compound': -0.296,
#    'neg': 0.099,
#    'neu': 0.901,
#    'pos': 0.0},
#   'text': 'En mi bootcamp, una compi hizo algo parecido pero con biopsias de tumores de mama para detectar si eran o no malignos'},
#  '5eaeca402908c7e2052a6b2c': {'score': {'compound': -0.5267,
#    'neg': 0.355,
#    'neu': 0.645,
#    'pos': 0.0},
#   'text': 'Su modelo no diferenciaba el covid, porque no existía jeje'},
#  '5eaeca402908c7e2052a6b2d': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://www.antena3.com/noticias/ciencia/dos-jovenes-espanoles-crean-app-capaz-localizar-coronavirus-radiografia-torax_202004225ea0838364242d000169c1f3.html>'},
#  '5eaeca402908c7e2052a6b2e': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Mirad, un TA de data de parttime en su día hizo algo así de proyecto final del bootcamp que estáis haciendo vosotros. Para que veáis que cosas tan chulis se pueden hacer'},
#  '5eaeca412908c7e2052a6b2f': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Los labs de hoy :rocket: : <https://github.com/ironhack-datalabs/datamad0320/tree/master/module-2/lab-intro-recommender-systems>\n<https://github.com/ironhack-datalabs/datamad0320/tree/master/module-2/lab-recommender-deepdive> <https://media.giphy.com/media/3o6Mb3kqC0Pecg3p96/giphy.gif>'},
#  '5eaeca412908c7e2052a6b30': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '``` idx = image == l```\n'},
#  '5eaeca412908c7e2052a6b31': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca412908c7e2052a6b32': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Buenos díaaaaaaaaaas!!!!! Haya ido, como haya ido el finde, ya es lunes, y comienza la semana 6. Comenzamos con una kata, 7kyu :muscle: para ir calentando para una nueva semana y conocimientos :nerd_face:  <https://www.codewars.com/kata/5d4c6809089c6e5031f189ed>'},
#  '5eaeca412908c7e2052a6b33': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'lectura fresquita para el veranito :sun_with_face: <!channel>'},
#  '5eaeca422908c7e2052a6b34': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'buenos dias <!channel> Algunos me faltan por rellenar la encuesta. Recordad que la teneis en la plataforma :face_with_monocle::grinning:'},
#  '5eaeca422908c7e2052a6b35': {'score': {'compound': 0.3818,
#    'neg': 0.191,
#    'neu': 0.479,
#    'pos': 0.33},
#   'text': 'Bueno, el mio se ha colado en una tele sin señal xD'},
#  '5eaeca422908c7e2052a6b36': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'import torchvision\nfrom imageProcessing import resizeImg, generateMask'},
#  '5eaeca422908c7e2052a6b37': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'cuando importo estas dos librerias'},
#  '5eaeca422908c7e2052a6b38': {'score': {'compound': -0.4019,
#    'neg': 0.31,
#    'neu': 0.69,
#    'pos': 0.0},
#   'text': 'cual comando en especifico lanza el error ?'},
#  '5eaeca432908c7e2052a6b39': {'score': {'compound': -0.1511,
#    'neg': 1.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': 'sorry!'},
#  '5eaeca432908c7e2052a6b3a': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'parece ser un problema de pytorch'},
#  '5eaeca432908c7e2052a6b3b': {'score': {'compound': -0.5267,
#    'neg': 0.468,
#    'neu': 0.532,
#    'pos': 0.0},
#   'text': 'yo tengo ubuntu, y no, no tuve problema'},
#  '5eaeca432908c7e2052a6b3c': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'mac'},
#  '5eaeca432908c7e2052a6b3d': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'en qué sistema operativa estás?'},
#  '5eaeca442908c7e2052a6b3e': {'score': {'compound': 0.34,
#    'neg': 0.0,
#    'neu': 0.844,
#    'pos': 0.156},
#   'text': 'Alguien ha tenido este problema con las librerias? estoy buscando en internet soluciones y nada..'},
#  '5eaeca442908c7e2052a6b3f': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'jajajajja tal cual'},
#  '5eaeca442908c7e2052a6b40': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'esa , esa'},
#  '5eaeca442908c7e2052a6b41': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'aajajajajaja'},
#  '5eaeca442908c7e2052a6b42': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca452908c7e2052a6b43': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'si, lo del uint8 tambien me ayudo ayer a salir de un atasco'},
#  '5eaeca452908c7e2052a6b44': {'score': {'compound': -0.5267,
#    'neg': 0.167,
#    'neu': 0.833,
#    'pos': 0.0},
#   'text': 'voy a mirarlo, es cierto que alguna conversión no se me hace bien, porque al final del proceso, mi array no es del tipo `uint8`'},
#  '5eaeca452908c7e2052a6b45': {'score': {'compound': -0.3595,
#    'neg': 0.034,
#    'neu': 0.966,
#    'pos': 0.0},
#   'text': 'Mi teoría es que algo te falla en la conversión de RGB a gris porque a mí me pasó algo parecido y ese era el fallo... En la parte 1 termino con dos np.array, uno del back y otro del fore, ambos de 3D, y al principio de la parte 2, los transformo a imagen con Image.fromarray(array.astype("uint8")), y luego los paso a escala de grises con convert() ... buaaa es que es un lío y no sé si me explico bien!'},
#  '5eaeca452908c7e2052a6b46': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'chicos entrare a zoom por si alguien quiere hablar sobre el lab'},
#  '5eaeca452908c7e2052a6b47': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<@U0102M3MFLJ>, antes de pasarlo a la función de convolve, los transformé a array\n```back_np = np.array(back_bnw)\nkernel = np.random.rand(20,20)```'},
#  '5eaeca462908c7e2052a6b48': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'perdonad, que he estado desconfinado del lab,'},
#  '5eaeca462908c7e2052a6b49': {'score': {'compound': -0.5696,
#    'neg': 0.092,
#    'neu': 0.884,
#    'pos': 0.024},
#   'text': 'Hola!! tengo una duda sobre esto. He conseguido estas mismas imagenes, pero según el enunciado en esa parte y también según el enunciado del challenge siguiente parece que hay que conseguir una unica imagen o array para el foreground y otra para el background, no? No sé si termino de entender bien los enunciados'},
#  '5eaeca462908c7e2052a6b4a': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'otra portada psicodelica para el album :joy::sob:'},
#  '5eaeca462908c7e2052a6b4b': {'score': {'compound': 0.0772,
#    'neg': 0.0,
#    'neu': 0.894,
#    'pos': 0.106},
#   'text': 'Ayer tuve problemas parecidos con el challenge 3, tratare hoy de solucionarlo'},
#  '5eaeca472908c7e2052a6b4c': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Hola JEsus, lo has solucionado ?'},
#  '5eaeca472908c7e2052a6b4d': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'el back_np viene de hacer el array a la imagen del background, ¿cómo la has pasado a escala de grises?'},
#  '5eaeca472908c7e2052a6b4e': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Hola Jesús! Para aplicar convolved los argumentos back_np y kernel tienen que ser de tipo np.array'},
#  '5eaeca472908c7e2052a6b4f': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': "Como argumentos de convolve2d he metido  esto:\n```convolve2d(back_np,kernel,'same')```"},
#  '5eaeca472908c7e2052a6b50': {'score': {'compound': -0.296,
#    'neg': 0.115,
#    'neu': 0.885,
#    'pos': 0.0},
#   'text': 'Como portada de un disco psicodélico está guay, pero creo que no es el resultado que se espera'},
#  '5eaeca482908c7e2052a6b51': {'score': {'compound': -0.296,
#    'neg': 0.239,
#    'neu': 0.761,
#    'pos': 0.0},
#   'text': 'A mí no se me aplica bien al fondo'},
#  '5eaeca482908c7e2052a6b52': {'score': {'compound': 0.34,
#    'neg': 0.0,
#    'neu': 0.769,
#    'pos': 0.231},
#   'text': 'Buenos días, alguien ha conseguido sacar bien el convolve2d?'},
#  '5eaeca482908c7e2052a6b53': {'score': {'compound': 0.6103,
#    'neg': 0.0,
#    'neu': 0.546,
#    'pos': 0.454},
#   'text': 'Ok, ok, osea que iba bien. ¡Muchas gracias!!'},
#  '5eaeca482908c7e2052a6b54': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '`rgb` del background, y `rgb` del foreground'},
#  '5eaeca482908c7e2052a6b55': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'son 6 matrices pues son 3 para cada mask'},
#  '5eaeca492908c7e2052a6b56': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca492908c7e2052a6b57': {'score': {'compound': 0.0772,
#    'neg': 0.0,
#    'neu': 0.902,
#    'pos': 0.098},
#   'text': 'Hola David, este creo que seria el outpur para ese challenge 1 del lab 2'},
#  '5eaeca492908c7e2052a6b58': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '¿A qué se refiere cuando dice que hay que aplicar las máscaras? ¿Hay que multiplicar cada una de las matrices del tensor RGB por las dos máscaras? (Es decir, acabaríamos con 6 matrices distintas)'},
#  '5eaeca492908c7e2052a6b59': {'score': {'compound': -0.3595,
#    'neg': 0.111,
#    'neu': 0.889,
#    'pos': 0.0},
#   'text': '¡Hola! Estoy un poco atascado con el laboratorio de image segmentation porque no termino de entender el enunciado de un apartado.'},
#  '5eaeca4a2908c7e2052a6b5a': {'score': {'compound': 0.4199,
#    'neg': 0.0,
#    'neu': 0.264,
#    'pos': 0.736},
#   'text': 'Thank you!'},
#  '5eaeca4a2908c7e2052a6b5b': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Gracias!'},
#  '5eaeca4a2908c7e2052a6b5c': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Muchas gracias David!! :smiley:'},
#  '5eaeca4a2908c7e2052a6b5d': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'A mi tampoco me deja, pero muchas gracias por el currazo!'},
#  '5eaeca4a2908c7e2052a6b5e': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Gracias David!:clap:'},
#  '5eaeca4b2908c7e2052a6b5f': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'para importar módulos locales hay que tirar de una librería que se llama `importlib`'},
#  '5eaeca4b2908c7e2052a6b60': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://zerowithdot.com/colab-workspace/>'},
#  '5eaeca4b2908c7e2052a6b61': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'averiguado!!!'},
#  '5eaeca4b2908c7e2052a6b62': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Bueno, pues ya está'},
#  '5eaeca4c2908c7e2052a6b63': {'score': {'compound': -0.3595,
#    'neg': 0.122,
#    'neu': 0.878,
#    'pos': 0.0},
#   'text': 'gracias Roberto! voy a echarle una par de vueltas más a colab y si no, pues ahí le tiro con esa solución'},
#  '5eaeca4c2908c7e2052a6b64': {'score': {'compound': 0.1779,
#    'neg': 0.0,
#    'neu': 0.914,
#    'pos': 0.086},
#   'text': 'pude resolver mi caso, por si quieres pasarlo, pasando la imagen  resized, como un  `thumbnail`  a la linea `mask = generateMask(thumb)`'},
#  '5eaeca4c2908c7e2052a6b65': {'score': {'compound': -0.5803,
#    'neg': 0.104,
#    'neu': 0.896,
#    'pos': 0.0},
#   'text': 'Gente , aquí tenéis la primera semana de vídeos cortados a la duración de la clase. Los dejo unos días y los borro para subir la semana dos.:. Slack no me deja hacer menciones a grupo, no se por qué, podéis contestar alguno con un @channel? <https://drive.google.com/open?id=1H1T8nQeZzpO4HzLB3v7lfUabko7WJfoS>'},
#  '5eaeca4c2908c7e2052a6b66': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Ni idea de como va colab, lo siento tío...'},
#  '5eaeca4d2908c7e2052a6b67': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'y aquí llevo mi mañana de sábado ...'},
#  '5eaeca4d2908c7e2052a6b68': {'score': {'compound': -0.296,
#    'neg': 0.196,
#    'neu': 0.804,
#    'pos': 0.0},
#   'text': 'todo bien, excepto porque no me importa el módulo imageProcessing'},
#  '5eaeca4d2908c7e2052a6b69': {'score': {'compound': -0.5574,
#    'neg': 0.205,
#    'neu': 0.795,
#    'pos': 0.0},
#   'text': 'En mi caso estaba pasando la imagen del bird.png sin haberle hecho el resize tambien'},
#  '5eaeca4d2908c7e2052a6b6a': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'he importado el repo desde mi github'},
#  '5eaeca4d2908c7e2052a6b6b': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'sí, a mi también me peta el kernel'},
#  '5eaeca4e2908c7e2052a6b6c': {'score': {'compound': -0.296,
#    'neg': 0.144,
#    'neu': 0.76,
#    'pos': 0.096},
#   'text': 'Lo he hecho en el jupyter directamente, y se me ha petao el ordenador al intentar correrlo sin reducir una imagen :sweat_smile:'},
#  '5eaeca4e2908c7e2052a6b6d': {'score': {'compound': 0.34,
#    'neg': 0.0,
#    'neu': 0.821,
#    'pos': 0.179},
#   'text': 'buenas, alguien ha hecho el lab de segmentación a través de google colab?'},
#  '5eaeca4e2908c7e2052a6b6e': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Ya me gustaría :wink:'},
#  '5eaeca4e2908c7e2052a6b6f': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Jajajaja'},
#  '5eaeca4f2908c7e2052a6b70': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<!channel> Buenos días chicos!!!! Que tal va ese lab? :slightly_smiling_face:  Si quereis ver las presentaciones de WebDev Part Time, empiezan a las 9:45 y durarán casi seguro hasta las 14h.\n\nOs paso el link de zoom:\n\n<https://us02web.zoom.us/j/959827908>'},
#  '5eaeca4f2908c7e2052a6b71': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': ':pray:'},
#  '5eaeca4f2908c7e2052a6b72': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'dejame que pruebe'},
#  '5eaeca4f2908c7e2052a6b73': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'jejejejje'},
#  '5eaeca4f2908c7e2052a6b74': {'score': {'compound': -0.296,
#    'neg': 0.524,
#    'neu': 0.476,
#    'pos': 0.0},
#   'text': 'espero no teneerlo'},
#  '5eaeca502908c7e2052a6b75': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'estoy justo ahi'},
#  '5eaeca502908c7e2052a6b76': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': '?'},
#  '5eaeca502908c7e2052a6b77': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '```ValueError: operands could not be broadcast together with shapes (256,360) (256,341) ```\n'},
#  '5eaeca502908c7e2052a6b78': {'score': {'compound': 0.4019,
#    'neg': 0.0,
#    'neu': 0.73,
#    'pos': 0.27},
#   'text': 'En la ultima parte del challenge 2, alguien ha tenido este problema:'},
#  '5eaeca512908c7e2052a6b79': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': ': 1:'},
#  '5eaeca512908c7e2052a6b7a': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'hola, pues si me congela el hacer los masks, estaba reiniciando, ya me conecto de nuevo !'},
#  '5eaeca512908c7e2052a6b7b': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'A mi me petó'},
#  '5eaeca512908c7e2052a6b7c': {'score': {'compound': 0.34,
#    'neg': 0.0,
#    'neu': 0.556,
#    'pos': 0.444},
#   'text': 'a mi me ha funcionado'},
#  '5eaeca522908c7e2052a6b7d': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'si quieres hablar en zoom y miramos'},
#  '5eaeca522908c7e2052a6b7e': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Hola chicos, a alguien mas le esta petando el lab 2, al crear las masks?'},
#  '5eaeca522908c7e2052a6b7f': {'score': {'compound': 0.2023,
#    'neg': 0.0,
#    'neu': 0.357,
#    'pos': 0.643},
#   'text': 'it’s important'},
#  '5eaeca522908c7e2052a6b80': {'score': {'compound': 0.5374,
#    'neg': 0.0,
#    'neu': 0.822,
#    'pos': 0.178},
#   'text': '<!channel> Hola chicos!! Please, rellenad la encuesta que teneis disponible en la plataforma de ironhack :slightly_smiling_face: Abrazos!!!'},
#  '5eaeca532908c7e2052a6b81': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Gracias, es para un amigo :upside_down_face:'},
#  '5eaeca532908c7e2052a6b82': {'score': {'compound': 0.34,
#    'neg': 0.0,
#    'neu': 0.556,
#    'pos': 0.444},
#   'text': 'y ¿cómo lo ha solucionado?'},
#  '5eaeca532908c7e2052a6b83': {'score': {'compound': -0.0772,
#    'neg': 0.158,
#    'neu': 0.702,
#    'pos': 0.14},
#   'text': 'Hola familia, a alguien que tenga mac le ha dado alguna vez este error: `URLError: '},
#  '5eaeca532908c7e2052a6b84': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'me podeis meter en la breakout?'},
#  '5eaeca532908c7e2052a6b85': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'hola!'},
#  '5eaeca542908c7e2052a6b86': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': ':slightly_smiling_face:'},
#  '5eaeca542908c7e2052a6b87': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<@U010F1E9KS8>, nos alquilas uno?'},
#  '5eaeca542908c7e2052a6b88': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'padres/madres alquilando niñas/os por horas en 3, 2, 1'},
#  '5eaeca542908c7e2052a6b89': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://1km.geomatico.es/>'},
#  '5eaeca552908c7e2052a6b8a': {'score': {'compound': -0.296,
#    'neg': 0.099,
#    'neu': 0.901,
#    'pos': 0.0},
#   'text': 'Si encontráis un niñ@ para sacarlo, aquí tenéis una aplicación para que no os alejéis más de 1 km de vuestra casa'},
#  '5eaeca552908c7e2052a6b8b': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca552908c7e2052a6b8c': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://media1.tenor.com/images/a19a33fb2ac2cb56f69a28f967c4e2f2/tenor.gif?itemid=4463733>'},
#  '5eaeca552908c7e2052a6b8d': {'score': {'compound': -0.296,
#    'neg': 0.268,
#    'neu': 0.732,
#    'pos': 0.0},
#   'text': 'cuando te dicen que no hay proyecto'},
#  '5eaeca562908c7e2052a6b8e': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca562908c7e2052a6b8f': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Nos espían :open_mouth: <https://media.giphy.com/media/YN6qUXj4HdXoY/giphy.gif>'},
#  '5eaeca562908c7e2052a6b90': {'score': {'compound': 0.0516,
#    'neg': 0.083,
#    'neu': 0.827,
#    'pos': 0.09},
#   'text': 'no es casualidad, habrá un programa hecho por alguna compañera que se ha dado cuenta de tus problemitas de los últimos días jejejejejeje :upside_down_face:'},
#  '5eaeca562908c7e2052a6b91': {'score': {'compound': 0.34,
#    'neg': 0.0,
#    'neu': 0.821,
#    'pos': 0.179},
#   'text': 'Justo me ha llegado esto hoy como aviso al correo :slightly_smiling_face: : <https://towardsdatascience.com/p-values-explained-by-data-scientist-f40a746cfc8>'},
#  '5eaeca572908c7e2052a6b92': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '```class Dinglemouse(object):\n    \n    def __init__(self):\n        self.name = None\n        self.sex  = None\n        self.age  = None\n        self.string = "Hello."\n    \n    def setAge(self, age):\n        if self.age:\n            self.string = self.string.replace(str(self.age), str(age))\n            self.age = age\n        else:\n            self.age = age\n            ag = f" I am {age}."\n            self.string = self.string   ag\n        return self\n        \n    def setSex(self, sex):\n        if self.sex:\n            sx_new="female" if sex=="F" else "male"\n            sx_old ="female" if self.sex=="F" else "male" \n            self.string = self.string.replace(sx_old, sx_new)\n            self.sex = sex\n        else:\n            self.sex = sex\n            sx = " I am female." if self.sex=="F" else " I am male."     \n            self.string = self.string   sx\n        return self\n\n        \n    def setName(self, name):\n        if self.name:  \n            self.string = self.string.replace(self.name, name)\n            self.name=name\n        else:\n            self.name = name\n            nam= f" My name is {name}."\n            self.string = self.string   nam\n        return self\n        \n    def hello(self):\n        return self.string```'},
#  '5eaeca572908c7e2052a6b93': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca572908c7e2052a6b94': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'hahahaha'},
#  '5eaeca572908c7e2052a6b95': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca582908c7e2052a6b96': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'si sergio nosotros si escuchamos!'},
#  '5eaeca582908c7e2052a6b97': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Holaa! Nos podéis meter en la breakout room?'},
#  '5eaeca582908c7e2052a6b98': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://towardsdatascience.com/statistical-tests-when-to-use-which-704557554740>'},
#  '5eaeca582908c7e2052a6b99': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'si, lleva  varios dias fallando github. :man-shrugging::man-shrugging::man-shrugging::man-shrugging::man-shrugging::man-shrugging:'},
#  '5eaeca582908c7e2052a6b9a': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://media3.giphy.com/media/vyVxeMNGUBT7q/giphy.gif>'},
#  '5eaeca592908c7e2052a6b9b': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://www.githubstatus.com/>'},
#  '5eaeca592908c7e2052a6b9c': {'score': {'compound': 0.7772,
#    'neg': 0.0,
#    'neu': 0.756,
#    'pos': 0.244},
#   'text': 'Es el momento perfecto para que veais ese webinar! Mola mucho, es super interesante.\nSerá muy util para vosotros.\nAdemás Germás es increíble!'},
#  '5eaeca592908c7e2052a6b9d': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Germán el LT de web es un crack y váis a flipar con él :slightly_smiling_face: y con todo lo que os puede enseñar!!!'},
#  '5eaeca592908c7e2052a6b9e': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'yo también os lo recomiendo mucho mucho'},
#  '5eaeca5a2908c7e2052a6b9f': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'ES MUUY INTERESANTE QUE VAYAIS!!  OS LO RECOMIENDO 100%'},
#  '5eaeca5a2908c7e2052a6ba0': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'aqui os dejo el enlace :slightly_smiling_face: :slightly_smiling_face: :slightly_smiling_face:'},
#  '5eaeca5a2908c7e2052a6ba1': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://www.crowdcast.io/e/f7o8llob/register>'},
#  '5eaeca5a2908c7e2052a6ba2': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<!channel> Chicos! Hoy a las 16h, German Álvarez hará un workshop sobre visualización de datos a las *16h*'},
#  '5eaeca5b2908c7e2052a6ba3': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'gracias!!!'},
#  '5eaeca5b2908c7e2052a6ba4': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca5b2908c7e2052a6ba5': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://stackoverflow.com/questions/51039161/how-to-add-a-label-on-each-circle-in-a-folium-circile-map-python>'},
#  '5eaeca5b2908c7e2052a6ba6': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '¡Gracias!'},
#  '5eaeca5c2908c7e2052a6ba7': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'aunque sea en formato web'},
#  '5eaeca5c2908c7e2052a6ba8': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://www.statsref.com/HTML/index.html>'},
#  '5eaeca5c2908c7e2052a6ba9': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Feliz día del libro'},
#  '5eaeca5c2908c7e2052a6baa': {'score': {'compound': -0.4184,
#    'neg': 0.1,
#    'neu': 0.9,
#    'pos': 0.0},
#   'text': 'dicen que nuestro trabajo no es bonito, que de eso se encargan los de front y los de UX/UI,\n¡no tienen ni idea! ¡nuestro trabajo es precioso!'},
#  '5eaeca5d2908c7e2052a6bab': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://towardsdatascience.com/adding-style-to-pandas-in-just-a-few-lines-of-code-be942f65b3a5>'},
#  '5eaeca5d2908c7e2052a6bac': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Gracias!!:)'},
#  '5eaeca5d2908c7e2052a6bad': {'score': {'compound': -0.5574,
#    'neg': 0.545,
#    'neu': 0.455,
#    'pos': 0.0},
#   'text': 'O sin considerar casos especiales'},
#  '5eaeca5d2908c7e2052a6bae': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca5e2908c7e2052a6baf': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca5e2908c7e2052a6bb0': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca5e2908c7e2052a6bb1': {'score': {'compound': -0.5267,
#    'neg': 0.087,
#    'neu': 0.913,
#    'pos': 0.0},
#   'text': 'En el siguiente enunciado de el lab-continuous-probability-distribution, con distribuiciones de longitud 1 y 100, no sereis capaces de ver nada. No se ni si un unico elemento se puede considerar distribuicion. Probad con diferentes valores, uno un par de ordenes de magnitud mas grande que el otro, e.g.: 1.000 y 100.000'},
#  '5eaeca5e2908c7e2052a6bb2': {'score': {'compound': -0.296,
#    'neg': 0.145,
#    'neu': 0.855,
#    'pos': 0.0},
#   'text': 'Si vuestro distribuidor de internet no os deja entrar, podéis probar desde Tor :slightly_smiling_face:'},
#  '5eaeca5f2908c7e2052a6bb3': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '@canal, os dejo aquí el link piratilla :stuck_out_tongue:  para descargaros el libro que recomendaba Marc. Pero en inglés: <https://libgen.is/search.php?req=Introductory Probability and Statistical Applications'},
#  '5eaeca5f2908c7e2052a6bb4': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Gracias Felipe'},
#  '5eaeca5f2908c7e2052a6bb5': {'score': {'compound': 0.0516,
#    'neg': 0.141,
#    'neu': 0.705,
#    'pos': 0.154},
#   'text': '<@U010H821HBR> <@U010F1E9KS8> no se que hemos liado pero mi ordenador ha petado :rolling_on_the_floor_laughing:'},
#  '5eaeca602908c7e2052a6bb6': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<!channel> chicos, estos apuntes estan en un repositiorio separado os acabo de pasar el link'},
#  '5eaeca602908c7e2052a6bb7': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'gracias!!'},
#  '5eaeca602908c7e2052a6bb8': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://github.com/boyander/probability>'},
#  '5eaeca602908c7e2052a6bb9': {'score': {'compound': 0.4019,
#    'neg': 0.0,
#    'neu': 0.748,
#    'pos': 0.252},
#   'text': 'marc puedes subir los apuntes de clase por favor?'},
#  '5eaeca612908c7e2052a6bba': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'creo que la idea es que hagáis todo lo que podáis :slightly_smiling_face:'},
#  '5eaeca612908c7e2052a6bbb': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'el que hay que hacer por parejas es el challenge1?'},
#  '5eaeca612908c7e2052a6bbc': {'score': {'compound': -0.296,
#    'neg': 0.145,
#    'neu': 0.855,
#    'pos': 0.0},
#   'text': 'creo que estoy con sergio pero con el usuario que no usa. puede ser?'},
#  '5eaeca612908c7e2052a6bbd': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://github.com/ironhack-datalabs/datamad0320/tree/master/module-2/lab-probability-distribution>'},
#  '5eaeca622908c7e2052a6bbe': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca622908c7e2052a6bbf': {'score': {'compound': -0.7101,
#    'neg': 0.055,
#    'neu': 0.945,
#    'pos': 0.0},
#   'text': 'Silvia, I could check it out with a little more time. There are actually 2 things you should consider so it would work. The first is the `strip` on the first line. It removes the extra spaces on the begining and end of the string. And the tests consider these spaces should be kept. If the string starts with a space, the first square of the pattern should be empty.\nThe second is the way you calculate the spaces, that is what is causing the index out of range Error. I think you use the `%3` becayse of the spaces surrounding each letter. But you add these spaces later. Besides, using the integer division `//` you round down and it may not fulfill the necesary quantity.'},
#  '5eaeca622908c7e2052a6bc0': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca622908c7e2052a6bc1': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Muchas gracias Felipe!! :grinning:'},
#  '5eaeca632908c7e2052a6bc2': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca632908c7e2052a6bc3': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'def pattern(rows, columns, s):\n    edge=\' ---\'\n    s  = " "*(rows*columns-len(s))\n    let=[e for e in s]\n    r=""\n    for i in range(rows):\n        for j in range (columns):\n            r =edge\n        r =" \\n"\n        for _ in range(columns):\n            print(let)\n            r ="| " let.pop(0) " "\n        r ="|" "\\n"\n    r =edge*columns \' \'\n    return r'},
#  '5eaeca632908c7e2052a6bc4': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca632908c7e2052a6bc5': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': ':top: Gif!'},
#  '5eaeca642908c7e2052a6bc6': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca642908c7e2052a6bc7': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'gracias por confirmar :rocket:'},
#  '5eaeca642908c7e2052a6bc8': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Gracias chicos!!!'},
#  '5eaeca652908c7e2052a6bc9': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'estaba intermitente'},
#  '5eaeca652908c7e2052a6bca': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://www.githubstatus.com/>'},
#  '5eaeca652908c7e2052a6bcb': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '15 minutos lleva caido :slightly_smiling_face:'},
#  '5eaeca652908c7e2052a6bcc': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'yeahh github is down'},
#  '5eaeca662908c7e2052a6bcd': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca662908c7e2052a6bce': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'alguien esta teniendo problemas con la conexion de github?'},
#  '5eaeca662908c7e2052a6bcf': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'y a mii!'},
#  '5eaeca662908c7e2052a6bd0': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<@U010G3H1PD5> puedes meterme en la breakout room por fi?'},
#  '5eaeca672908c7e2052a6bd1': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://media.giphy.com/media/11zXBCAb9soCQM/giphy.gif>'},
#  '5eaeca672908c7e2052a6bd2': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://media.giphy.com/media/Ix6QPu53WlB6w/giphy.gif>'},
#  '5eaeca672908c7e2052a6bd3': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://github.com/ironhack-datalabs/datamad0320/tree/master/module-2/lab-storytelling-data-visualization>\n<https://github.com/ironhack-datalabs/datamad0320/tree/master/module-2/lab-tableau-data-visualization>'},
#  '5eaeca672908c7e2052a6bd4': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Pues mejor, porque ya con abrir zoom, slack y vscode a la vez, mi ordenador empieza a llorar RAM y amenaza con emanciparse de la vida...'},
#  '5eaeca682908c7e2052a6bd5': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'De acuerdo con <@U010G3H1PD5>'},
#  '5eaeca682908c7e2052a6bd6': {'score': {'compound': -0.296,
#    'neg': 0.091,
#    'neu': 0.909,
#    'pos': 0.0},
#   'text': '<@U010H826R1D>, como veas. Yo no lo veo particularmente interesante. Y si tienes la alternativa de utilizar otro ordenador, seguramente funcionará mejor que en VM'},
#  '5eaeca682908c7e2052a6bd7': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'A los que estén interesados en instalar la máquina virtual, debéis instalar la version 6.1 de Virtualbox para que os funcione el `.ova` de el enlace anterior de microsoft.\n`sudo apt-get install virtualbox-6.1`'},
#  '5eaeca692908c7e2052a6bd8': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Me refiero a la encuesta anterior a esa publicacion, sobre las VM'},
#  '5eaeca692908c7e2052a6bd9': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Felipe, te refieres a la encuenta de todas las semanas? O es otra diferente?'},
#  '5eaeca692908c7e2052a6bda': {'score': {'compound': -0.7319,
#    'neg': 0.12,
#    'neu': 0.88,
#    'pos': 0.0},
#   'text': 'Felipe, yo tengo VirtualBox sin configurar. Descargué la imagen preconfigurada de windows que enlazó Marc, pero no me funcionó. Desde entonces he usado tableau con otro ordenador de trabajo que tengo con windows. Debería intentar configurar VB en Ubuntu de todas formas? Pruebo con otra imagen igual?'},
#  '5eaeca692908c7e2052a6bdb': {'score': {'compound': 0.296,
#    'neg': 0.0,
#    'neu': 0.784,
#    'pos': 0.216},
#   'text': 'Si está descargado, ok. Lo demás vemos esa tarde.'},
#  '5eaeca6a2908c7e2052a6bdc': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Hola Felipe, tengo el archivo OVA descargado, pero tuve algunas dificultades para instalarlo correctamente en virtualbox que te comento esta tarde!'},
#  '5eaeca6a2908c7e2052a6bdd': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Todos que necesitais instalar máquina virtual, aceded a <https://developer.microsoft.com/es-es/windows/downloads/virtual-machines/> y descargad la version para VirtualBox. Tened en cuenta que es un fichero de casi 20GB y TARDARÁ a descargarse. Lo vais a necesitar para seguir. Asi que dejadlo descargando durante la comida y descomprimirlo a una carpeta.'},
#  '5eaeca6a2908c7e2052a6bde': {'score': {'compound': 0.4574,
#    'neg': 0.0,
#    'neu': 0.667,
#    'pos': 0.333},
#   'text': '<!channel> Por favor, responded `todos` a la encuesta.'},
#  '5eaeca6a2908c7e2052a6bdf': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rank.html>'},
#  '5eaeca6b2908c7e2052a6be0': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://pages.github.com/>'},
#  '5eaeca6b2908c7e2052a6be1': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca6b2908c7e2052a6be2': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca6b2908c7e2052a6be3': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca6c2908c7e2052a6be4': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca6c2908c7e2052a6be5': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'jejeje'},
#  '5eaeca6c2908c7e2052a6be6': {'score': {'compound': -0.7249,
#    'neg': 0.469,
#    'neu': 0.531,
#    'pos': 0.0},
#   'text': 'Sorry chicos, era para los TA no para vosotros!!! My fault'},
#  '5eaeca6d2908c7e2052a6be7': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Gracias!'},
#  '5eaeca6d2908c7e2052a6be8': {'score': {'compound': 0.34,
#    'neg': 0.0,
#    'neu': 0.833,
#    'pos': 0.167},
#   'text': '<@U010EAT0XFF> <@U010G3H1PD5>, me volvéis a meter? que mi ordenador ha decidido unirse al confinamiento...'},
#  '5eaeca6d2908c7e2052a6be9': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'jajajajaja'},
#  '5eaeca6d2908c7e2052a6bea': {'score': {'compound': -0.296,
#    'neg': 0.115,
#    'neu': 0.885,
#    'pos': 0.0},
#   'text': 'estoy de camino, que siempre a esta hora *zoom* se echa la siesta y no me deja conectarme jeje :rocket:'},
#  '5eaeca6e2908c7e2052a6beb': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'ahora si! Gracias!'},
#  '5eaeca6e2908c7e2052a6bec': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'Ya estás, pero tienes que adentrarla'},
#  '5eaeca6e2908c7e2052a6bed': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': ':pray:'},
#  '5eaeca6e2908c7e2052a6bee': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'felipe? jajaja'},
#  '5eaeca6f2908c7e2052a6bef': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': ':wink:'},
#  '5eaeca6f2908c7e2052a6bf0': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<@U010G3H1PD5> puede :slightly_smiling_face:'},
#  '5eaeca6f2908c7e2052a6bf1': {'score': {'compound': 0.4019,
#    'neg': 0.0,
#    'neu': 0.69,
#    'pos': 0.31},
#   'text': 'puedes ponerme en la breakroom por favor?'},
#  '5eaeca702908c7e2052a6bf2': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': 'hOLA CLARA'},
#  '5eaeca702908c7e2052a6bf3': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 0.0},
#   'text': ''},
#  '5eaeca702908c7e2052a6bf4': {'score': {'compound': 0.0,
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0},
#   'text': '<https://www.flerlagetwins.com/2019/07/mongodb.html> TABLEAU :heart: MONGODB'},
#  '5eaeca702908c7e2052a6bf5': {'score': {'compound': 0.3802,
#    'neg': 0.0,
#    'neu': 0.853,
#    'pos': 0.147},
#   'text': 'buenos dias <!channel> algunos tendreis la survey del viernes por realizar  ¿ podriais completarla please? grachieeee :wink:'},
#  'chat_sentiment': -0.015440273037542656}

# %%
import json
from pymongo import MongoClient
import random 
from datetime import datetime
from bson import ObjectId
import requests
import pandas as pd
dbName = "dbChat"
mongodbURL = f"mongodb+srv://tzvuccy:Silvia89!@cluster0-qywyc.mongodb.net/test?retryWrites=true&w=majority"
print(mongodbURL)
client = MongoClient(mongodbURL, connectTimeoutMS=2000,serverSelectionTimeoutMS=2000)
db = client.get_database("dbChat")
# Out:
# mongodb+srv://tzvuccy:Silvia89!@cluster0-qywyc.mongodb.net/test?retryWrites=true&w=majority
